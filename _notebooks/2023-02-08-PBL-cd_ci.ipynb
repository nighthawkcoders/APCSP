# %% [markdown]
# # CI/CD on Flask, Integration of Github Pages and AWS
# > Continuous Integration and Continuous Delivery. Information on connecting Github Pages with AWS.
#
# - title: CI/CD on Flask, Integration of Github Pages and AWS
# - toc: true
# - categories: []
# - image: /images/python.png
# - type: pbl
# - week: 22
